# %%
# This is the file I used when working with the whole activity files.

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy as sc

from sklearn.preprocessing import MinMaxScaler

import os

# %%
# features to analyse
#mean
def feature_mean(feature_name,accel_gyro_data):
    mean = accel_gyro_data.mean()
    mean_transposed_df = mean.to_frame().T
    mean_transposed_df.columns = ["Accel_X_"+feature_name ,"Accel_Y_" +feature_name ,"Accel_Z_" +feature_name,"Gyro_X_" +feature_name, "Gyro_Y_" + feature_name ,"Gyro_Z_" +feature_name ,"Magno_X_" +feature_name, "Magno_Y_" +feature_name ,"Magno_Z_" +feature_name, "Accel_Vecdis_" +feature_name, "Gyro_Vecdis_" +feature_name ,"Magno_Vecdis_" +feature_name]
    return mean_transposed_df

#std
def feature_std(feature_name,accel_gyro_data):
    std = accel_gyro_data.std()
    std_transposed_df = std.to_frame().T
    std_transposed_df.columns = ["Accel_X_"+feature_name ,"Accel_Y_" +feature_name ,"Accel_Z_" +feature_name,"Gyro_X_" +feature_name, "Gyro_Y_" + feature_name ,"Gyro_Z_" +feature_name ,"Magno_X_" +feature_name, "Magno_Y_" +feature_name ,"Magno_Z_" +feature_name, "Accel_Vecdis_" +feature_name, "Gyro_Vecdis_" +feature_name ,"Magno_Vecdis_" +feature_name]
    return std_transposed_df

#kurtosis
def feature_kurtosis(feature_name,accel_gyro_data):
    kurtosis = accel_gyro_data.kurtosis()
    kurtosis_transposed_df = kurtosis.to_frame().T
    kurtosis_transposed_df.columns = ["Accel_X_"+feature_name ,"Accel_Y_" +feature_name ,"Accel_Z_" +feature_name,"Gyro_X_" +feature_name, "Gyro_Y_" + feature_name ,"Gyro_Z_" +feature_name ,"Magno_X_" +feature_name, "Magno_Y_" +feature_name ,"Magno_Z_" +feature_name, "Accel_Vecdis_" +feature_name, "Gyro_Vecdis_" +feature_name ,"Magno_Vecdis_" +feature_name]
    return kurtosis_transposed_df

#median
def feature_median(feature_name,accel_gyro_data):
    median = accel_gyro_data.median()
    median_transposed_df = median.to_frame().T
    median_transposed_df.columns = ["Accel_X_"+feature_name ,"Accel_Y_" +feature_name ,"Accel_Z_" +feature_name,"Gyro_X_" +feature_name, "Gyro_Y_" + feature_name ,"Gyro_Z_" +feature_name ,"Magno_X_" +feature_name, "Magno_Y_" +feature_name ,"Magno_Z_" +feature_name, "Accel_Vecdis_" +feature_name, "Gyro_Vecdis_" +feature_name ,"Magno_Vecdis_" +feature_name]
    return median_transposed_df

#skewness
def feature_skewness(feature_name,accel_gyro_data):
    skewness = accel_gyro_data.skew()
    skewness_transposed_df = skewness.to_frame().T
    skewness_transposed_df.columns = ["Accel_X_"+feature_name ,"Accel_Y_" +feature_name ,"Accel_Z_" +feature_name,"Gyro_X_" +feature_name, "Gyro_Y_" + feature_name ,"Gyro_Z_" +feature_name ,"Magno_X_" +feature_name, "Magno_Y_" +feature_name ,"Magno_Z_" +feature_name, "Accel_Vecdis_" +feature_name, "Gyro_Vecdis_" +feature_name ,"Magno_Vecdis_" +feature_name]
    return skewness_transposed_df

# vector distance mean
def feature_sum(feature_name,accel_gyro_data):
    sum_ = accel_gyro_data.sum()
    sum_transposed_df = sum_.to_frame().T
    sum_transposed_df.columns = ["Accel_X_"+feature_name ,"Accel_Y_" +feature_name ,"Accel_Z_" +feature_name,"Gyro_X_" +feature_name, "Gyro_Y_" + feature_name ,"Gyro_Z_" +feature_name ,"Magno_X_" +feature_name, "Magno_Y_" +feature_name ,"Magno_Z_" +feature_name, "Accel_Vecdis_" +feature_name, "Gyro_Vecdis_" +feature_name ,"Magno_Vecdis_" +feature_name]
    return sum_transposed_df

def calculate_zero_crossing_rate(accel_data):
    accel_data = (accel_data - np.mean(accel_data)) / np.std(accel_data)
        # Calculate Zerocrossing rate.
    zero_crossings = np.nonzero(np.diff(np.signbit(accel_data)))[0]
    zcr = len(zero_crossings) / (2.0 * len(accel_data))
    return zcr

def feature_zero_cross(feature_name,accel_gyro_data):
    zero_crossing_rates = {}
    for column in accel_gyro_data.columns:
        zcr = calculate_zero_crossing_rate(accel_gyro_data[column])
        zero_crossing_rates[column] = zcr

    zcr_series = pd.Series(zero_crossing_rates)
    zcr_transposed_df = zcr_series.to_frame().T
    zcr_transposed_df.columns = ["Accel_X_" + feature_name ,"Accel_Y_" + feature_name ,"Accel_Z_" + feature_name,"Gyro_X_" + feature_name, "Gyro_Y_" + feature_name ,"Gyro_Z_" + feature_name ,"Magno_X_" + feature_name, "Magno_Y_" +feature_name ,"Magno_Z_" +feature_name]
    return zcr_transposed_df


# vector distance mean
def diff_sum(feature_name,accel_gyro_data):
    sum_ = accel_gyro_data.diff().sum()
    sum_transposed_df = sum_.to_frame().T
    sum_transposed_df.columns = ["Accel_X_"+feature_name ,"Accel_Y_" +feature_name ,"Accel_Z_" +feature_name,"Gyro_X_" +feature_name, "Gyro_Y_" + feature_name ,"Gyro_Z_" +feature_name ,"Magno_X_" +feature_name, "Magno_Y_" +feature_name ,"Magno_Z_" +feature_name, "Accel_Vecdis_" +feature_name, "Gyro_Vecdis_" +feature_name ,"Magno_Vecdis_" +feature_name]
    return sum_transposed_df


# create table 
def get_concated_features(accel_gyro_data):
    
    # accel_gyro_data['Accel'] = np.sqrt(np.sum(accel_gyro_data.iloc[:, 0:3] ** 2, axis = 1))
    # accel_gyro_data['Gyro'] = np.sqrt(np.sum(accel_gyro_data.iloc[:, 3:6] ** 2, axis = 1))
    # accel_gyro_data['Magno'] = np.sqrt(np.sum(accel_gyro_data.iloc[:, 6:9] ** 2, axis = 1))
    
    df1 = feature_mean("mean",accel_gyro_data)
    df2 = feature_median("median",accel_gyro_data)
    df3 = feature_std("std",accel_gyro_data)
    df4 = feature_kurtosis("kurtosis",accel_gyro_data)
    df5 =feature_skewness("skewness",accel_gyro_data)
    df6 = feature_sum("sum",accel_gyro_data)
    df7 = feature_zero_cross("zero_cross_rate", accel_gyro_data)
    df8 = diff_sum("diff_sum", accel_gyro_data)

    df = [df1, df2, df3, df4, df5, df6,df7,df8]
    result_df = pd.concat(df, axis=1)

    return result_df

# %%
scaler = MinMaxScaler()

# read data in
#directory_path = 'C:\\Users\\fried\\Documents\\URI\\ELE_591\\syncedfiles\\syncedfiles'

directory_path = 'C:\\Users\\fried\\Documents\\URI\\ELE_591\\syncedfiles\\IdentifierRM_Sync_WatchData'


dataframes = []

# Loop through the files in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):
        # Construct the full file path
        file_path = os.path.join(directory_path, filename)
        
        # Read the CSV file into a DataFrame and append it to the list
        df = pd.read_csv(file_path,low_memory=False)
        print(filename)
        
        if 'Unnamed: 0' in df.columns:
            df = df.drop(columns='Unnamed: 0')
        
        #index = dataframe[df['Hyperactive_Restless'] == -100].index
        #df.drop(index , inplace=True)
       
        #substring = 'peers'
        #df_1 = df[~df['HyperactiveBehaviourType'].str.contains(substring,na=False)]
            
        #substring = 'self'
        #df_wout = df_1[~df_1['HyperactiveBehaviourType'].str.contains(substring, na=False)]
    
    
        
        # group by hyperactive behavior
        grouped_df = df.groupby('Hyperactive_Restless')

        df_new = []

        
        group_1_exists = 1 in grouped_df.groups
        group_2_exists = 2 in grouped_df.groups
        if group_1_exists and not group_2_exists:
            df_hyper = grouped_df.get_group(1)
            substring = 'peers'
            df_1 = df_hyper[~df_hyper['HyperactiveBehaviourType'].str.contains(substring,na=False)]
            substring = 'self'
            df_wout = df_1[~df_1['HyperactiveBehaviourType'].str.contains(substring, na=False)]
            #df_hyper = grouped_df.get_group(1)
            if not df_wout.empty:
                df_hyper_not_normalized = df_wout.iloc[:, 4:13]
                #df_normalized = pd.DataFrame(scaler.fit_transform(df.iloc[:, 4:13]), columns=df.columns)
                df_hyper_normalized = pd.DataFrame(scaler.fit_transform(df_wout.iloc[:, 4:13]), columns=df_wout.iloc[:, 4:13].columns)
                hyper_result = get_concated_features(df_hyper_normalized,df_hyper_not_normalized)#.iloc[:, 4:13])
                hyper_result['type'] = 1
                df_new.append(hyper_result)
        elif group_2_exists and not group_1_exists:
            df_hyper = grouped_df.get_group(2)
            substring = 'peers'
            df_1 = df_hyper[~df_hyper['HyperactiveBehaviourType'].str.contains(substring,na=False)]
            substring = 'self'
            df_wout = df_1[~df_1['HyperactiveBehaviourType'].str.contains(substring, na=False)]
            if not df_wout.empty:
                df_hyper_not_normalized = df_wout.iloc[:, 4:13]
                df_hyper_normalized = pd.DataFrame(scaler.fit_transform(df_wout.iloc[:, 4:13]), columns=df_wout.iloc[:, 4:13].columns)
                hyper_result = get_concated_features(df_hyper_normalized,df_hyper_not_normalized)#.iloc[:, 4:13])
                hyper_result['type'] = 1
                df_new.append(hyper_result)
        elif group_1_exists and group_2_exists :
            value1_df = grouped_df.get_group(1)
            value2_df = grouped_df.get_group(2)
            substring = 'peers'
            df_1 = value1_df[~value1_df['HyperactiveBehaviourType'].str.contains(substring,na=False)]
            df_2 = value2_df[~value2_df['HyperactiveBehaviourType'].str.contains(substring,na=False)]
            substring = 'self'
            df_wout_1 = df_1[~df_1['HyperactiveBehaviourType'].str.contains(substring, na=False)]
            df_wout_2 = df_2[~df_2['HyperactiveBehaviourType'].str.contains(substring, na=False)]
            # Concatenate the two DataFrames
            df_hyper = pd.concat([df_wout_1, df_wout_2])
            if not df_hyper.empty:
                df_hyper_not_normalized = df_hyper.iloc[:, 4:13]
                df_hyper_normalized = pd.DataFrame(scaler.fit_transform(df_hyper.iloc[:, 4:13]), columns=df_hyper.iloc[:, 4:13].columns)
                hyper_result = get_concated_features(df_hyper_normalized,df_hyper_not_normalized)#.iloc[:, 4:13])
                hyper_result['type'] = 1
                df_new.append(hyper_result)

        
        
        
        group_0_exists = 0 in grouped_df.groups
        if group_0_exists:
            df_nonhyper = grouped_df.get_group(0)
            df_nonhyper_not_normalized = df_nonhyper.iloc[:, 4:13]
            df_nonhyper_normalized = pd.DataFrame(scaler.fit_transform(df_nonhyper.iloc[:, 4:13]), columns=df_nonhyper.iloc[:, 4:13].columns)
            nonhyper_result = get_concated_features(df_nonhyper_normalized,df_nonhyper_not_normalized)#.iloc[:, 4:13])
            nonhyper_result['type'] = 0
            df_new.append(nonhyper_result)
        
        #hyper_result['type'] = 1
        #nonhyper_result['type'] = 0
        #df_new.append(nonhyper_result)
        #df_new.append(hyper_result)
        
        
        if df_new:
            resulting_df = pd.concat(df_new, axis=0)
        
            # split file name and add columns
            file_components = filename.split('_')
            resulting_df['Participent'] = file_components[0]
            resulting_df['Watch name'] = file_components[2]
            resulting_df['Activity'] = file_components[3]
        
            dataframes.append(resulting_df)
        
        
# Print the concatenated DataFrame
resulting_df_final = pd.concat(dataframes, axis=0)
resulting_df_final.head()

resulting_df_final.to_csv('C:\\Users\\fried\\Documents\\URI\\ELE_591\\syncedfiles\\analysis_table_revised_2_new.csv', index=False)
# Out:
# P10_Left_SSW4WearOS02_A1.csv
# P10_Left_SSW4WearOS02_A2.csv
# P10_Left_SSW4WearOS02_A3.csv
# P10_Left_SSW4WearOS02_A4.csv
# P10_Right_SSW4WearOS01_A3.csv
# P10_Right_SSW4WearOS01_A4.csv
# P10_Right_SSW4WearOS05_A1.csv
# P11_Left_SSW4WearOS01_A1.csv
# P11_Left_SSW4WearOS01_A2.csv
# P11_Left_SSW4WearOS01_A3.csv
# P11_Left_SSW4WearOS01_A4.csv
# P11_Right_SSW4WearOS08_A1.csv
# P11_Right_SSW4WearOS08_A2.csv
# P11_Right_SSW4WearOS08_A3.csv
# P12_Left_SSW4WearOS03_A3.csv
# P12_Left_SSW4WearOS03_A4.csv
# P12_Right_SSW4WearOS04_A3.csv
# P12_Right_SSW4WearOS04_A4.csv
# P13_Left_SSW4WearOS03_A1.csv
# P13_Left_SSW4WearOS03_A2.csv
# P13_Left_SSW4WearOS03_A3.csv
# P13_Left_SSW4WearOS03_A4.csv
# P13_Right_SSW4WearOS04_A1.csv
# P13_Right_SSW4WearOS04_A2.csv
# P13_Right_SSW4WearOS04_A3.csv
# P13_Right_SSW4WearOS04_A4.csv
# P14_Left_SSW4WearOS03_A1.csv
# P14_Left_SSW4WearOS03_A2.csv
# P14_Left_SSW4WearOS03_A3.csv
# P14_Left_SSW4WearOS03_A4.csv
# P14_Right_SSW4WearOS02_A4.csv
# P14_Right_SSW4WearOS04_A1.csv
# P14_Right_SSW4WearOS04_A2.csv
# P15_Left_SSW4WearOS07_A2.csv
# P15_Left_SSW4WearOS07_A3.csv
# P15_Left_SSW4WearOS07_A4.csv
# P15_Right_SSW4WearOS08_A1.csv
# P15_Right_SSW4WearOS08_A2.csv
# P15_Right_SSW4WearOS08_A4.csv
# P16_Left_SSW4WearOS01_A1.csv
# P16_Left_SSW4WearOS01_A2.csv
# P16_Left_SSW4WearOS01_A3.csv
# P16_Left_SSW4WearOS01_A4.csv
# P16_Right_SSW4WearOS08_A3.csv
# P16_Right_SSW4WearOS08_A4.csv
# P18_Left_SSW4WearOS03_A1.csv
# P18_Left_SSW4WearOS03_A2.csv
# P18_Left_SSW4WearOS03_A3.csv
# P18_Left_SSW4WearOS03_A4.csv
# P18_Right_SSW4WearOS04_A1.csv
# P18_Right_SSW4WearOS04_A2.csv
# P18_Right_SSW4WearOS04_A3.csv
# P18_Right_SSW4WearOS04_A4.csv
# P19_Left_SSW4WearOS03_A1.csv
# P19_Left_SSW4WearOS03_A2.csv
# P19_Left_SSW4WearOS03_A3.csv
# P20_Left_SSW4WearOS07_A1.csv
# P20_Left_SSW4WearOS07_A2.csv
# P20_Left_SSW4WearOS07_A3.csv
# P20_Right_SSW4WearOS08_A1.csv
# P20_Right_SSW4WearOS08_A2.csv
# P20_Right_SSW4WearOS08_A3.csv
# P21_Left_SSW4WearOS05_A1.csv
# P21_Left_SSW4WearOS05_A2.csv
# P21_Left_SSW4WearOS05_A3.csv
# P21_Right_SSW4WearOS06_A1.csv
# P21_Right_SSW4WearOS06_A2.csv
# P21_Right_SSW4WearOS06_A3.csv
# P22_Left_SSW4WearOS01_A2.csv
# P22_Left_SSW4WearOS01_A3.csv
# P22_Left_SSW4WearOS01_A4.csv
# P22_Right_SSW4WearOS08_A1.csv
# P22_Right_SSW4WearOS08_A2.csv
# P22_Right_SSW4WearOS08_A3.csv
# P22_Right_SSW4WearOS08_A4.csv
# P23_Left_SSW4WearOS03_A1.csv
# P23_Left_SSW4WearOS03_A2.csv
# P23_Left_SSW4WearOS03_A4.csv
# P23_Right_SSW4WearOS04_A1.csv
# P23_Right_SSW4WearOS04_A2.csv
# P23_Right_SSW4WearOS04_A3.csv
# P23_Right_SSW4WearOS04_A4.csv
# P24_Left_SSW4WearOS02_A1.csv
# P24_Left_SSW4WearOS02_A2.csv
# P24_Left_SSW4WearOS02_A3.csv
# P24_Left_SSW4WearOS02_A4.csv
# P24_Right_SSW4WearOS06_A1.csv
# P24_Right_SSW4WearOS06_A2.csv
# P24_Right_SSW4WearOS06_A3.csv
# P24_Right_SSW4WearOS06_A4.csv
# P5_Left_SSW4WearOS07_A1.csv
# P5_Left_SSW4WearOS07_A3.csv
# P5_Right_SSW4WearOS08_A1.csv
# P5_Right_SSW4WearOS08_A2.csv
# P5_Right_SSW4WearOS08_A3.csv
# P5_Right_SSW4WearOS08_A4.csv
# P6_Left_SSW4WearOS03_A1.csv
# P6_Left_SSW4WearOS03_A2.csv
# P6_Left_SSW4WearOS03_A3.csv
# P6_Left_SSW4WearOS03_A4.csv
# P6_Right_SSW4WearOS04_A1.csv
# P6_Right_SSW4WearOS04_A2.csv
# P6_Right_SSW4WearOS04_A3.csv
# P7_Left_SSW4WearOS01_A4.csv
# P7_Left_SSW4WearOS07_A1.csv
# P7_Left_SSW4WearOS07_A2.csv
# P7_Left_SSW4WearOS07_A3.csv
# P7_Right_SSW4WearOS08_A2.csv
# P7_Right_SSW4WearOS08_A3.csv
# P7_Right_SSW4WearOS08_A4.csv
# P8_Left_SSW4WearOS03_A1.csv
# P8_Left_SSW4WearOS03_A2.csv
# P8_Left_SSW4WearOS03_A3.csv
# P8_Left_SSW4WearOS03_A4.csv
# P8_Right_SSW4WearOS04_A1.csv
# P8_Right_SSW4WearOS04_A2.csv
# P8_Right_SSW4WearOS04_A3.csv
# P8_Right_SSW4WearOS04_A4.csv
# P9_Left_SSW4WearOS03_A1.csv
# P9_Left_SSW4WearOS03_A2.csv
# P9_Left_SSW4WearOS03_A3.csv
# P9_Left_SSW4WearOS03_A4.csv
# P9_Right_SSW4WearOS04_A1.csv
# P9_Right_SSW4WearOS04_A2.csv
# P9_Right_SSW4WearOS04_A4.csv

# %%
resulting_df_final.head(-5)
# Out:
#     Accel_X_mean  Accel_Y_mean  Accel_Z_mean  Gyro_X_mean  Gyro_Y_mean  \
# 0       0.650536      0.615739      0.586771     0.489904     0.447446
# 0       0.672722      0.552235      0.495836     0.635197     0.483850
# 0       0.727661      0.412909      0.442897     0.560745     0.525353
# 0       0.440156      0.688193      0.482277     0.372123     0.541570
# 0       0.453248      0.544648      0.516417     0.660516     0.509467
# ..           ...           ...           ...          ...          ...
# 0       0.647692      0.539806      0.548225     0.453181     0.458121
# 0       0.654539      0.642417      0.486048     0.574304     0.470703
# 0       0.505337      0.515021      0.531067     0.485910     0.483869
# 0       0.143439      0.827267      0.459478     0.458661     0.469261
# 0       0.490041      0.438908      0.536803     0.531564     0.467655
#
#     Gyro_Z_mean  Magno_X_mean  Magno_Y_mean  Magno_Z_mean  Accel_Vecdis_mean  \
# 0      0.562563      0.306750      0.445059      0.339938           1.077979
# 0      0.565094      0.297593      0.613222      0.337589           1.020066
# 0      0.416024      0.502239      0.649155      0.434543           0.966909
# 0      0.548358      0.575336      0.541700      0.440472           0.952986
# 0      0.510048      0.600221      0.619787      0.377235           0.902374
# ..          ...           ...           ...           ...                ...
# 0      0.483418      0.280843      0.335702      0.311124           1.008615
# 0      0.457556      0.225850      0.381706      0.382992           1.042940
# 0      0.467885      0.444252      0.372262      0.278899           0.901619
# 0      0.490828      0.314849      0.408773      0.316887           0.958429
# 0      0.460649      0.497982      0.350170      0.336587           0.858396
#
#     ...  Magno_X_diff_sum  Magno_Y_diff_sum  Magno_Z_diff_sum  \
# 0   ...         -0.132541          0.049233          0.048686
# 0   ...         -0.382221          0.146324          0.250897
# 0   ...          0.007507         -0.340214         -0.155074
# 0   ...          0.205425          0.135082          0.164045
# 0   ...         -0.324100         -0.219657          0.415270
# ..  ...               ...               ...               ...
# 0   ...         -0.246644         -0.208622         -0.126560
# 0   ...         -0.338189          0.129659         -0.162512
# 0   ...          0.096818         -0.065359          0.017233
# 0   ...          0.197248          0.512042          0.192937
# 0   ...         -0.376437         -0.201807          0.140159
#
#     Accel_Vecdis_diff_sum  Gyro_Vecdis_diff_sum  Magno_Vecdis_diff_sum  type  \
# 0               -0.036949              0.021467              -0.058898     0
# 0                0.012465              0.001642               0.027484     0
# 0                0.127581             -0.038879              -0.316874     1
# 0               -0.047246              0.000537               0.286554     0
# 0                0.344017              0.189202              -0.044665     1
# ..                    ...                   ...                    ...   ...
# 0                0.120506             -0.004360              -0.328518     1
# 0                0.134892              0.082187              -0.054957     0
# 0               -0.008232             -0.010041               0.063426     1
# 0                0.044123             -0.019975               0.499319     0
# 0                0.240698              0.118850              -0.308954     1
#
#     Participent    Watch name  Activity
# 0           P10  SSW4WearOS02    A1.csv
# 0           P10  SSW4WearOS02    A2.csv
# 0           P10  SSW4WearOS02    A3.csv
# 0           P10  SSW4WearOS02    A3.csv
# 0           P10  SSW4WearOS02    A4.csv
# ..          ...           ...       ...
# 0            P9  SSW4WearOS03    A3.csv
# 0            P9  SSW4WearOS03    A3.csv
# 0            P9  SSW4WearOS03    A4.csv
# 0            P9  SSW4WearOS03    A4.csv
# 0            P9  SSW4WearOS04    A1.csv
#
# [217 rows x 97 columns]

# %%
resulting_df = pd.concat(dataframes, axis=0)
resulting_df.shape
# Out:
# (222, 97)

# %%
df.head()
# Out:
#    level_0  index                       DataTS                      EventTS  \
# 0     4069   4069   05/07/2023 10:00:00.013 AM   01/01/0001 12:00:00.000 AM
# 1     4070   4070   05/07/2023 10:00:00.048 AM   01/01/0001 12:00:00.000 AM
# 2     4071   4071   05/07/2023 10:00:00.081 AM   01/01/0001 12:00:00.000 AM
# 3     4072   4072   05/07/2023 10:00:00.115 AM   01/01/0001 12:00:00.000 AM
# 4     4073   4073   05/07/2023 10:00:00.150 AM   01/01/0001 12:00:00.000 AM
#
#     Accel_X   Accel_Y   Accel_Z   Gyro_X   Gyro_Y   Gyro_Z  ...  NewClock  \
# 0     0.110    -0.957     0.178    0.544   -0.005   -0.133  ...  00:00:01
# 1     0.107    -1.024     0.139   -0.016   -0.001   -0.040  ...  00:00:01
# 2     0.121    -1.006     0.169    0.408    0.002   -0.117  ...  00:00:01
# 3     0.101    -0.985     0.192    0.260    0.028   -0.035  ...  00:00:01
# 4     0.108    -1.003     0.193    0.563   -0.009   -0.104  ...  00:00:01
#
#    Elapsed_Time  OffSeat  Hyperactive_Restless    HyperactiveBehaviourType  \
# 0       0:00:01        1                     1  Standing up while working
# 1       0:00:01        1                     1  Standing up while working
# 2       0:00:01        1                     1  Standing up while working
# 3       0:00:01        1                     1  Standing up while working
# 4       0:00:01        1                     1  Standing up while working
#
#    SecondHyperactiveBehaviourType Inattentive Inattentive.1 SecondInattentive  \
# 0                             NaN           0           NaN               NaN
# 1                             NaN           0           NaN               NaN
# 2                             NaN           0           NaN               NaN
# 3                             NaN           0           NaN               NaN
# 4                             NaN           0           NaN               NaN
#
#   new_zeroTS
# 0   00:00:01
# 1   00:00:01
# 2   00:00:01
# 3   00:00:01
# 4   00:00:01
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['level_0', 'index', ' DataTS', ' EventTS', ' Accel_X', ' Accel_Y',
#        ' Accel_Z', ' Gyro_X', ' Gyro_Y', ' Gyro_Z', ' Magno_X', ' Magno_Y',
#        ' Magno_Z', ' Heartrate', ' AudioLevel', ' BatteryLevel', 'timestamp',
#        'timestamp_str', 'timestamp_str_seconds', 'NewClock', 'Elapsed_Time',
#        'OffSeat', 'Hyperactive_Restless', 'HyperactiveBehaviourType',
#        'SecondHyperactiveBehaviourType', 'Inattentive', 'Inattentive.1',
#        'SecondInattentive', 'new_zeroTS'],
#       dtype='object')

# %%
df["HyperactiveBehaviourType"].unique()
# Out:
# array(['Standing up while working ', nan,
#        'Moving the chair back and forth', 'Talking to peers', '-100'],
#       dtype=object)

# %%
file = 'C:\\Users\\fried\\Documents\\URI\\ELE_591\\syncedfiles\\IdentifierRM_Sync_WatchData\\P5_Right_SSW4WearOS08_A4.csv'
dataframe = pd.read_csv(file,low_memory=False)
dataframe.head()

grouped_df = dataframe.groupby('Hyperactive_Restless')
